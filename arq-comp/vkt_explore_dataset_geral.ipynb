# %%
import sweetviz as sv
import pandas as pd

#df_v4 = pd.read_csv('datasets/vkt_geral_v4_rm.csv')
df_v6 = pd.read_csv('datasets/2019/vkt_v6.csv')
df_v7 = pd.read_csv('datasets/2019/vkt_v7.csv')

comp=sv.compare(df_v6,df_v7)
#anl=sv.analyze(df_v6)
comp.show_html(filepath='sweetviz/SWEETVIZ_REPORT_2019_v6_v7.html')
#anl.show_html(filepath='SWEETVIZ_REPORT_2017_v6.html')

# %%
df_v7.describe()
# Out:
#                 Ano    Quantidade  Consumo_Gasolina  Consumo_Alcool  \
# count  3.044873e+06  3.044873e+06      2.124986e+06    1.061129e+06
# mean   2.000741e+03  1.022286e+01      1.304472e+01    8.932160e+00
# std    1.235917e+01  8.616066e+01      5.792127e+00    3.911673e+00
# min    1.900000e+03  6.600169e-07      8.675000e+00    5.700000e+00
# 25%    1.992000e+03  4.011433e-01      1.148281e+01    7.200000e+00
# 50%    2.003000e+03  9.695096e-01      1.222903e+01    8.318977e+00
# 75%    2.011000e+03  3.365532e+00      1.264611e+01    8.913043e+00
# max    2.017000e+03  2.800598e+04      4.965000e+01    3.280000e+01
#
#        Consumo_Diesel  VKT_Preliminar       Relacao  Volume_Gasolina  \
# count   621824.000000    3.044873e+06  3.044873e+06     2.124986e+06
# mean         6.425594    1.582310e+05  3.508638e-01     1.125545e+04
# std          2.297041    1.349627e+06  1.478288e-01     7.896697e+04
# min          2.650000    4.074945e-03  6.851179e-02     3.548734e-04
# ...

# %%
df_v7['Volume_Gasolina'].count()
# Out:
# 2124986
