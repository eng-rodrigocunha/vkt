# %%
import pandas as pd
df_comb_rm = pd.read_csv('datasets/base_combustiveis_precos.csv', low_memory=False, decimal=',')

# %%
df_comb_rm.rename(columns={'Estado - Sigla': 'UF', 'Valor de Venda': 'Valor_Venda', 'Data da Coleta': 'Data'}, inplace = True)

df_rms = pd.read_csv('datasets/rms_uf_resumida_rev02.csv')

df_comb_rm = df_comb_rm[df_comb_rm[['UF', 'Municipio']].apply(tuple, axis=1).isin(df_rms[['UF','Municipio']].apply(tuple, axis=1))]
df_comb_rm = pd.merge(df_comb_rm, df_rms[['Municipio', 'UF', 'RM']], on=['Municipio', 'UF'], how='left')

df_comb_rm['Data'] = pd.to_datetime(df_comb_rm['Data'])

# %%
df_comb_rm
# Out:
#         Regiao - Sigla  UF   Municipio                               Revenda  \
# 0                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 1                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 2                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 3                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 4                   CO  DF    BRASILIA  GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.
# ...                ...  ..         ...                                   ...
# 2742777              N  AC  RIO BRANCO          AUTO POSTO JAGUAR LTDA - EPP
# 2742778              N  AC  RIO BRANCO          AUTO POSTO JAGUAR LTDA - EPP
# 2742779              N  AM      MANAUS        RUBI COMERCIO DE PETROLEO LTDA
# 2742780              N  AM      MANAUS        RUBI COMERCIO DE PETROLEO LTDA
# 2742781              N  AM      MANAUS        RUBI COMERCIO DE PETROLEO LTDA
#
#              CNPJ da Revenda                                  Nome da Rua  \
# 0         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 1         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 2         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 3         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 4         00.603.738/0001-43  QI-QUADRA INTERNA 18  LOTES 47, 49, 51 E 53
# ...                      ...                                          ...
# 2742777   18.327.432/0001-77                                 RUA UIRAPURU
# 2742778   18.327.432/0001-77                                 RUA UIRAPURU
# 2742779   20.703.180/0001-85                        AVENIDA CARVALHO LEAL
# 2742780   20.703.180/0001-85                        AVENIDA CARVALHO LEAL
# 2742781   20.703.180/0001-85                        AVENIDA CARVALHO LEAL
#
#         Numero Rua                         Complemento        Bairro  \
# 0              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 1              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 2              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 3              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 4              S/N                                 NaN    TAGUATINGA
# ...            ...                                 ...           ...
# 2742777        S/N  LOTE  01 AO 08            QUADRA37      OURICURI
# 2742778        S/N  LOTE  01 AO 08            QUADRA37      OURICURI
# 2742779       1562                                 NaN  CACHOEIRINHA
# 2742780       1562                                 NaN  CACHOEIRINHA
# 2742781       1562                                 NaN  CACHOEIRINHA
#
#                Cep     Produto       Data Valor_Venda Valor de Compra  \
# 0        07178-580    GASOLINA 2013-02-01       2,599          2,1955
# 1        07178-580      ETANOL 2013-02-01       1,859          1,5582
# 2        07178-580      DIESEL 2013-02-01       2,029             NaN
# 3        07178-580         GNV 2013-02-01       1,399             NaN
# 4        72315-000    GASOLINA 2013-02-01        2,83             NaN
# ...            ...         ...        ...         ...             ...
# 2742777  69903-200      DIESEL 2019-12-30        4.54          3.7036
# 2742778  69903-200  DIESEL S10 2019-12-30        4.59          3.7234
# 2742779  69065-150    GASOLINA 2019-12-30        3.87             NaN
# 2742780  69065-150      ETANOL 2019-12-30        3.29             NaN
# 2742781  69065-150  DIESEL S10 2019-12-30        3.92             NaN
#
#         Unidade de Medida                      Bandeira  \
# 0              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 1              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 2              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 3                 R$ / m³  PETROBRAS DISTRIBUIDORA S.A.
# 4              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# ...                   ...                           ...
# 2742777        R$ / litro                         SABBÁ
# 2742778        R$ / litro                         SABBÁ
# 2742779        R$ / litro                        BRANCA
# 2742780        R$ / litro                        BRANCA
# 2742781        R$ / litro                        BRANCA
#
#                                                         RM
# 0                        Região Metropolitana de São Paulo
# 1                        Região Metropolitana de São Paulo
# 2                        Região Metropolitana de São Paulo
# 3                        Região Metropolitana de São Paulo
# 4        Região Integrada de Desenvolvimento do Distrit...
# ...                                                    ...
# 2742777                                         Rio Branco
# 2742778                                         Rio Branco
# 2742779                     Região Metropolitana de Manaus
# 2742780                     Região Metropolitana de Manaus
# 2742781                     Região Metropolitana de Manaus
#
# [2742782 rows x 17 columns]

# %%
df_comb_rm.dtypes
# Out:
# Regiao - Sigla               object
# UF                           object
# Municipio                    object
# Revenda                      object
# CNPJ da Revenda              object
# Nome da Rua                  object
# Numero Rua                   object
# Complemento                  object
# Bairro                       object
# Cep                          object
# Produto                      object
# Data                 datetime64[ns]
# Valor_Venda                  object
# Valor de Compra              object
# Unidade de Medida            object
# Bandeira                     object
# RM                           object
# dtype: object

# %%
df_comb_rm['Valor_Venda'] = df_comb_rm['Valor_Venda'].apply(lambda x: x.replace(',', '.'))
df_comb_rm['Valor_Venda'] = pd.to_numeric(df_comb_rm['Valor_Venda'])
df_comb_rm['Ano'] = pd.DatetimeIndex(df_comb_rm['Data']).year

# %%
df_comb_rm
# Out:
#         Regiao - Sigla  UF   Municipio                               Revenda  \
# 0                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 1                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 2                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 3                   SE  SP   GUARULHOS              AUTO POSTO SAKAMOTO LTDA
# 4                   CO  DF    BRASILIA  GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.
# ...                ...  ..         ...                                   ...
# 2742777              N  AC  RIO BRANCO          AUTO POSTO JAGUAR LTDA - EPP
# 2742778              N  AC  RIO BRANCO          AUTO POSTO JAGUAR LTDA - EPP
# 2742779              N  AM      MANAUS        RUBI COMERCIO DE PETROLEO LTDA
# 2742780              N  AM      MANAUS        RUBI COMERCIO DE PETROLEO LTDA
# 2742781              N  AM      MANAUS        RUBI COMERCIO DE PETROLEO LTDA
#
#              CNPJ da Revenda                                  Nome da Rua  \
# 0         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 1         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 2         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 3         49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 4         00.603.738/0001-43  QI-QUADRA INTERNA 18  LOTES 47, 49, 51 E 53
# ...                      ...                                          ...
# 2742777   18.327.432/0001-77                                 RUA UIRAPURU
# 2742778   18.327.432/0001-77                                 RUA UIRAPURU
# 2742779   20.703.180/0001-85                        AVENIDA CARVALHO LEAL
# 2742780   20.703.180/0001-85                        AVENIDA CARVALHO LEAL
# 2742781   20.703.180/0001-85                        AVENIDA CARVALHO LEAL
#
#         Numero Rua                         Complemento        Bairro  \
# 0              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 1              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 2              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 3              S/N                 KM 210,5-SENT SP/RJ    BONSUCESSO
# 4              S/N                                 NaN    TAGUATINGA
# ...            ...                                 ...           ...
# 2742777        S/N  LOTE  01 AO 08            QUADRA37      OURICURI
# 2742778        S/N  LOTE  01 AO 08            QUADRA37      OURICURI
# 2742779       1562                                 NaN  CACHOEIRINHA
# 2742780       1562                                 NaN  CACHOEIRINHA
# 2742781       1562                                 NaN  CACHOEIRINHA
#
#                Cep     Produto       Data  Valor_Venda Valor de Compra  \
# 0        07178-580    GASOLINA 2013-02-01        2.599          2,1955
# 1        07178-580      ETANOL 2013-02-01        1.859          1,5582
# 2        07178-580      DIESEL 2013-02-01        2.029             NaN
# 3        07178-580         GNV 2013-02-01        1.399             NaN
# 4        72315-000    GASOLINA 2013-02-01        2.830             NaN
# ...            ...         ...        ...          ...             ...
# 2742777  69903-200      DIESEL 2019-12-30        4.540          3.7036
# 2742778  69903-200  DIESEL S10 2019-12-30        4.590          3.7234
# 2742779  69065-150    GASOLINA 2019-12-30        3.870             NaN
# 2742780  69065-150      ETANOL 2019-12-30        3.290             NaN
# 2742781  69065-150  DIESEL S10 2019-12-30        3.920             NaN
#
#         Unidade de Medida                      Bandeira  \
# 0              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 1              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 2              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 3                 R$ / m³  PETROBRAS DISTRIBUIDORA S.A.
# 4              R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# ...                   ...                           ...
# 2742777        R$ / litro                         SABBÁ
# 2742778        R$ / litro                         SABBÁ
# 2742779        R$ / litro                        BRANCA
# 2742780        R$ / litro                        BRANCA
# 2742781        R$ / litro                        BRANCA
#
#                                                         RM   Ano
# 0                        Região Metropolitana de São Paulo  2013
# 1                        Região Metropolitana de São Paulo  2013
# 2                        Região Metropolitana de São Paulo  2013
# 3                        Região Metropolitana de São Paulo  2013
# 4        Região Integrada de Desenvolvimento do Distrit...  2013
# ...                                                    ...   ...
# 2742777                                         Rio Branco  2019
# 2742778                                         Rio Branco  2019
# 2742779                     Região Metropolitana de Manaus  2019
# 2742780                     Região Metropolitana de Manaus  2019
# 2742781                     Região Metropolitana de Manaus  2019
#
# [2742782 rows x 18 columns]

# %%
df_comb_rm.dtypes
# Out:
# Regiao - Sigla               object
# UF                           object
# Municipio                    object
# Revenda                      object
# CNPJ da Revenda              object
# Nome da Rua                  object
# Numero Rua                   object
# Complemento                  object
# Bairro                       object
# Cep                          object
# Produto                      object
# Data                 datetime64[ns]
# Valor_Venda                 float64
# Valor de Compra              object
# Unidade de Medida            object
# Bandeira                     object
# RM                           object
# Ano                           int64
# dtype: object

# %%
df_comb_rm_g = df_comb_rm.groupby(['RM', 'Ano', 'Produto',])['Valor_Venda'].mean()
df_comb_rm_g = df_comb_rm_g.reset_index()

df_comb_rm_g

#df_comb_rm_g.to_csv('datasets/base_combustiveis_precos_rm.csv')
# Out:
#                RM   Ano     Produto  Valor_Venda
# 0    Campo Grande  2013      DIESEL     2.432378
# 1    Campo Grande  2013  DIESEL S10     2.608672
# 2    Campo Grande  2013      ETANOL     2.083764
# 3    Campo Grande  2013    GASOLINA     2.933738
# 4    Campo Grande  2013         GNV     1.984121
# ..            ...   ...         ...          ...
# 874    Rio Branco  2018    GASOLINA     4.923493
# 875    Rio Branco  2019      DIESEL     4.353934
# 876    Rio Branco  2019  DIESEL S10     4.404831
# 877    Rio Branco  2019      ETANOL     3.929688
# 878    Rio Branco  2019    GASOLINA     4.795990
#
# [879 rows x 4 columns]

# %%
df_comb_rm_rel = df_comb_rm_g[((df_comb_rm_g['Produto'] == 'GASOLINA') | (df_comb_rm_g['Produto'] == 'ETANOL'))]
df_comb_rm_rel

#preco_gasolina = df_preco_comb_rm[((df_preco_comb_rm['Produto'] == 'GASOLINA') & (df_preco_comb_rm['Ano'] == ano) & (df_preco_comb_rm['RM'] == df['RM']))]['Preco_Venda']
#preco_alcool = df_preco_comb_rm[((df_preco_comb_rm['Produto'] == 'ALCOOL') & (df_preco_comb_rm['Ano'] == ano) & (df_preco_comb_rm['RM'] == df['RM']))]['Preco_Venda']
# Out:
#                RM   Ano   Produto  Valor_Venda
# 2    Campo Grande  2013    ETANOL     2.083764
# 3    Campo Grande  2013  GASOLINA     2.933738
# 7    Campo Grande  2014    ETANOL     2.106596
# 8    Campo Grande  2014  GASOLINA     2.991693
# 12   Campo Grande  2015    ETANOL     2.247934
# ..            ...   ...       ...          ...
# 870    Rio Branco  2017  GASOLINA     4.283360
# 873    Rio Branco  2018    ETANOL     3.914698
# 874    Rio Branco  2018  GASOLINA     4.923493
# 877    Rio Branco  2019    ETANOL     3.929688
# 878    Rio Branco  2019  GASOLINA     4.795990
#
# [378 rows x 4 columns]

# %%
df_comb_rm_rel = df_comb_rm_rel.pivot(index=['RM', 'Ano'], columns='Produto', values='Valor_Venda')
df_comb_rm_rel = df_comb_rm_rel.reset_index()
df_comb_rm_rel
# Out:
# Produto            RM   Ano    ETANOL  GASOLINA
# 0        Campo Grande  2013  2.083764  2.933738
# 1        Campo Grande  2014  2.106596  2.991693
# 2        Campo Grande  2015  2.247934  3.216077
# 3        Campo Grande  2016  2.748215  3.359293
# 4        Campo Grande  2017  3.040702  3.588838
# ..                ...   ...       ...       ...
# 184        Rio Branco  2015  3.039747  3.782039
# 185        Rio Branco  2016  3.330560  4.026330
# 186        Rio Branco  2017  3.641423  4.283360
# 187        Rio Branco  2018  3.914698  4.923493
# 188        Rio Branco  2019  3.929688  4.795990
#
# [189 rows x 4 columns]

# %%
df_comb_rm_rel['Relacao'] = (1 / (1 + 0.001685*((6567.5754)**(df_comb_rm_rel['ETANOL']/df_comb_rm_rel['GASOLINA']))))
df_comb_rm_rel
# Out:
# Produto            RM   Ano    ETANOL  GASOLINA   Relacao
# 0        Campo Grande  2013  2.083764  2.933738  0.535623
# 1        Campo Grande  2014  2.106596  2.991693  0.548991
# 2        Campo Grande  2015  2.247934  3.216077  0.560239
# 3        Campo Grande  2016  2.748215  3.359293  0.308964
# 4        Campo Grande  2017  3.040702  3.588838  0.257042
# ..                ...   ...       ...       ...       ...
# 184        Rio Branco  2015  3.039747  3.782039  0.336543
# 185        Rio Branco  2016  3.330560  4.026330  0.292149
# 186        Rio Branco  2017  3.641423  4.283360  0.252261
# 187        Rio Branco  2018  3.914698  4.923493  0.353678
# 188        Rio Branco  2019  3.929688  4.795990  0.306574
#
# [189 rows x 5 columns]

# %%
df_comb_rm_rel.to_csv('datasets/base_combustiveis_precos_rel_rm.csv')
